# %% [markdown]
# # WEB 4일차
#
# ### Bootstrap

# %% [markdown]
# <b>CDN</b>
#
# Content Delivery(Distribution) Network
#
# 컨텐츠(CSS, JS, Image, Text 등)를 효율적으로 전달하기 위해
# 여러 노드를 가진 네트워크에서 데이터를 제공하는 시스템
#
# 개별 end-user의 가까운 서버를 통해 빠르게 전달 가능(지리적 이점)
# 외부 서버를 활용함으로써 본인 서버의 부하가 적어짐

# %% [markdown]
# <b>spacing</b>
#
# - vw: viewpoint width
# - vh: viewpoint height
# - rem(상대적인 단위): html tag가 가지고 있는 font size에 비례 (기본 html의 font size: 16px)
#     - 다른 요소와의 조화를 위해서 rem이 필요할 것으로 보임
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>font-family</b>
#
# 유저의 컴퓨터에 폰트가 존재한다면 사용
#
#
# <b>font-face</b>
#
# @: 규칙을 설정하는 것
# CDN을 활용해서 font를 연결

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# x축 가운데 정렬
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 마진 상쇄(margin collapse)
#
# 마진이 겹치면 큰 것만 적용되고, 나머지는 없어짐

# %% [markdown]
# Carousel: 슬라이드를 순환하면서 보여주는 구조

# %% [markdown]
# ### 반응형 웹(Resposive Web)
#
# 부트스트랩을 쓰는 가장 큰 이유 중 하나
#
# <b>Responsive Web Design</b>
#
# 다양한 화면 크기를 가진 디바이스들이 등장함에 따라 responsive web design 개념이 등장
# 반응형 웹은 별도의 기술 이름이 아닌 웹 디자인에 대한 접근 방식, 반응형 레이아웃 작성에 도움이 되는 사례들의 모음 등을 기술하는데 사용되는 용어
#
# ex) Media Queries, Flexbox, Bootstrap Grid System ...

# %% [markdown]
# ### Bootstrap Grid System
#
# <b>The Grid System</b>
#
# CSS가 아닌편집 다자인에서 나온 개념으로 구성 요소를 잘 배치해서 시각적으로 좋은 결과물을 만들기 위함
# 기본적으로 안쪽에 있는 요소들의 오와 열을 맞추는 것에서 기인
# 정보 구조와 배열을 체계적으로 작성하여 정보의 질서를 부여하는 시스템
#
# <b>Web에도 GRid system이 들어오다</b>
#
# 요소들의 디자인과 배치에 도움을 주는 시스템
#
# 기본 요소
# - Column: 실제 컨텐츠를 포함하는 부분
# - Gutter: 칼럼과 칼럼 사이의 공간 (사이 간격)
# - Container: column들을 담고 있는 공간
#
# Bootstrap Grid System은 flexbox로 제작됨
#
# Container, rows, column으로 컨텐츠를 배치하고 정렬
#
# 반드시 기억해야할 2가지!
# 1. 12개의 column
# 2. 6개의 grid breakpoints

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# offset: 공백의 크기
