# %% [markdown]
# # 웹 3일차

# %% [markdown]
# ### float
#
# 박스를 왼쪽 혹은 오른쪽으로 이동시켜 텍스트를 포함 인라인 요소들이 주변을 wrapping 하도록 함
# 요소가 Noraml flow를 벗어나도록 함
#
# <b>float 속성</b>
# none: 기본값
# left: 요소를 왼쪽으로 띄움
# right: 요소를 오른쪽으로 띄움
#
#
# <b>float 예시</b>
#
# ```
# <body>
#     <div class="box left">float left</div>
#     <p>lorem300 자동 완성으로 길~게</p>
# </body>
# ```
#
# &nbsp;
#
# ```
# .box{
#     width: 150px;
#     height: 150px;
#     border: 1px solid black;
#     background-color: crimson;
#     color: white;
#     margin-right: 30px;
# }
#
# .left{
#     float: left;
# }
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="style/layout.css">
#     <title>Document</title>
# </head>
# <body>
#     <div class="container">
#         <div class="header"></div>
#         <div class="section-left left"></div>
#         <div class="section-right left"></div>
#         <div class="footer"></div>
#     </div>
# </body>
# </html>
# ```
#
# &nbsp;
#
# ```
# .header{
#     height: 100px;
#     background-color: aquamarine;
# }
#
# .section-left{
#     height: 500px;
#     width: 30%;
#     background-color: bisque;
# }
#
# .section-right{
#     height: 500px;
#     width: 70%;
#     background-color: skyblue;
# }
#
# .footer{
#     height: 100px;
#     background-color: yellowgreen;
#     clear: both;
# }
#
# .left{
#     float: left;
# }
#
# ```

# %% [markdown]
# <b>float 정리</b>
#
# float는 레이아웃을 구성하기 위해 필수적으로 활용되었으나, 최근 flexbox, grid 등장과 함께 사용도가 낮아짐
#
# float 활용 전략 - Normal Flow에서 벗어난 레이아웃 구성
# - 원하는 요소들을 float로 지정하여 배치

# %% [markdown]
# ### flexbox
#
# <b>Layout을 위해 탄생한 Flexbox</b>
#
# (수동값 부여 없이)
# 1. 수직 정렬
# 2. 아이템 너비와 높이 혹은 간격을 동일하게 배치

# %% [markdown]
# <b>CSS Flexible Box layout</b>
#
# 행과 열 형태로 아이템들을 배치하는 1차원 레이아웃 모델
#
# 축
# - main axis(메인 축)
# - cross axis(교차 축)
#
# 구성요소
# - Flex Container(부모 요소)
# - Flex Item(자식 요소)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Flexbox 축</b>
#
# flex-direction: row
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Flexbox 구성 요소</b>
#
# Flex Container(부모 요소)
# - flexbox layout을 형성하는 가장 기본적인 모델
# - flex item들이 놓여있는 영역
# - display 속성을 flex 혹은 inline-flex로 지정
#
# Flex item(자식 요소)
# - 컨테이너에 속해 있는 컨텐츠(박스)

# %% [markdown]
# <b>flexbox 시작</b>
#
# ```
# .flex-container{
#     display: flex;
#     flex-direction: row;
# }
# ```
#
# 만약 각각의 아이템이 저마다의 높이를 가지고 있다면?
# Flex는 자동으로 맞춰준다.
# Layout 배치가 매우 쉬워진다!

# %% [markdown]
# <b>Flex 속성</b>
#
# 배치 설정
# - flex-direction
# - flex-wrap
#
# 공간 나누기
# - justify-content (main axis)
# - align-content (cross axis)
#
# 정렬
# - align-items(모든 아이템을 cross axis 기준으로)
# - align-self(개별 아이템)

# %% [markdown]
# <b>flex 속성: flex-direction</b>
#
# - Main axis 기준 방향 설정
# - 역방향의 경우 HTML 태그 선언 순서와 시각적으로 다르니 유의
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>flex 속성: flex-wrap</b>
#
# 아이템이 컨테이너를 벗어나는 경우 해당 영역 내에 배치되도록 설정
# 즉, 기본적으로 컨테이너 영역을 벗어나지 않도록 함
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# <b> Flex 속성: justify-content (메인축 기준)</b>
#
# Main axis를 기준으로 공간 배분
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Flex 속성: align-content (cross axis 기준)</b>
#
# wrapping 한 상태임 아래는
#
# Cross axis를 기준으로 공간 배분 (아이템이 한 줄로 배치되는 경우를 확인할 수 없음)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Flex 속성: justfy-content & align-content</b>
#
# 공간 배분
#
# - flex-start(기본값): 아이템들을 axis 시작점으로
# - flex-end:아이템들을 axis 끝 쪽으로
# - center: 아이템들을 axis 중앙으로
# - space-between: 아이템 사이의 간격을 균일하게 분배
# - space-around: 아이템을 둘러싼 영역을 균일하게 분배 (가질 수 있는 영역을 반으로 나눠서 양쪽에)
# - space-evenly: 전체 영역에서 아이템 간 간격을 균일하게 분배

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# <b>Flex 속성: align-items &align-self</b>
#
# Cross axis를 중심으로
# - stretch(기본값): 컨테이너를 가득 채움
# - flex-start: 위
# - flex-end: 아래
# - center: 가운데
# - baseline: 텍스트 baseline에 기준선을 맞춤

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# grow반대 shrink (비율조정)
